# %%
import cv2 as cv
import numpy as np
from IPython.display import Image, display
from picamera import PiCamera
from zumi.util.screen import Screen
import time

# Load the predefined dictionary
dictionary = cv.aruco.Dictionary_get(cv.aruco.DICT_6X6_250)
# Initialize the detector parameters using default values
parameters =  cv.aruco.DetectorParameters_create()

#aquire a camera image

camera = PiCamera()

try:
    screen = Screen()
    camera.rotation = 180
    #camera.set_resolution()
    #camera.set_resolution()
    #camera.resolution = (1024,768)
    camera.resolution = (320,240)
        
    print("hello from jupyter")
    for i in range(0,50):
        screen.draw_text("take a picture"+str(i))
        camera.capture("test.jpg")
        frame = cv.imread("test.jpg")
        markerCorners, markerIds, rejectedCandidates = cv.aruco.detectMarkers(frame, dictionary, parameters=parameters)
        cv.aruco.drawDetectedMarkers(frame, markerCorners, markerIds)

        xsum = 0
        if (len(markerCorners)>0):
            for corner in markerCorners[0][0]:
                #display(corner)
                xsum+=corner[0]
            xmid = int(xsum/4)
            #display(xmid)
            cv.circle(frame,(xmid,120), 3, (0,0,255), -1)
            cv.imwrite("result.png",frame)
            display(Image(filename="result.png"))

finally:
    camera.close()
# Out:
# hello from jupyter
# array([139., 138.], dtype=float32)
# array([141., 195.], dtype=float32)
# array([ 73., 200.], dtype=float32)
# array([ 79., 141.], dtype=float32)
# array([118., 147.], dtype=float32)
# array([114., 191.], dtype=float32)
# array([ 59., 196.], dtype=float32)
# array([ 70., 152.], dtype=float32)
# array([125., 192.], dtype=float32)
# array([107., 153.], dtype=float32)
# array([155., 154.], dtype=float32)
# array([175., 201.], dtype=float32)
# array([216., 116.], dtype=float32)
# array([239., 101.], dtype=float32)
# array([242., 108.], dtype=float32)
# array([218., 124.], dtype=float32)
# array([241., 128.], dtype=float32)
# array([265., 114.], dtype=float32)
# array([269., 122.], dtype=float32)
# array([244., 137.], dtype=float32)
# array([244., 132.], dtype=float32)
# array([267., 118.], dtype=float32)
# array([272., 126.], dtype=float32)
# array([246., 141.], dtype=float32)
# array([258., 235.], dtype=float32)
# array([247., 193.], dtype=float32)
# array([291., 179.], dtype=float32)
# array([307., 219.], dtype=float32)
# array([243., 119.], dtype=float32)
# array([267., 105.], dtype=float32)
# array([270., 113.], dtype=float32)
# array([245., 127.], dtype=float32)
# array([240., 118.], dtype=float32)
# array([263., 104.], dtype=float32)
# array([267., 111.], dtype=float32)
# array([242., 127.], dtype=float32)
# array([236., 207.], dtype=float32)
# array([228., 169.], dtype=float32)
# array([267., 155.], dtype=float32)
# array([278., 191.], dtype=float32)
# array([202., 164.], dtype=float32)
# array([150., 160.], dtype=float32)
# array([147., 108.], dtype=float32)
# array([199., 110.], dtype=float32)
# array([186., 160.], dtype=float32)
# array([123., 186.], dtype=float32)
# array([ 87., 123.], dtype=float32)
# array([152.,  92.], dtype=float32)
# array([172., 172.], dtype=float32)
# array([129., 119.], dtype=float32)
# array([182.,  77.], dtype=float32)
# array([226., 131.], dtype=float32)
# array([185., 143.], dtype=float32)
# array([115., 188.], dtype=float32)
# array([ 80., 119.], dtype=float32)
# array([147.,  79.], dtype=float32)
# array([115., 219.], dtype=float32)
# array([ 41., 205.], dtype=float32)
# array([ 65., 129.], dtype=float32)
# array([134., 140.], dtype=float32)
# array([101., 194.], dtype=float32)
# array([ 95., 157.], dtype=float32)
# array([140., 137.], dtype=float32)
# array([149., 168.], dtype=float32)
# array([213., 104.], dtype=float32)
# array([170., 121.], dtype=float32)
# array([154.,  78.], dtype=float32)
# array([202.,  62.], dtype=float32)
